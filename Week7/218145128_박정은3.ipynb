# %% [markdown]
# # 7.4  무선청소기 모델별 비교 분석

# %% [markdown]
# ### 7.4.1 데이터 살펴보기

# %%
import pandas as pd
danawa_data=pd.read_excel('2_danawa_data_final.xlsx')
danawa_data.head()
# Out:
#        카테고리   회사명                      제품       가격  사용시간    흡입력
# 0  핸디/스틱청소기  LG전자  오브제컬렉션 코드제로 A9S AU9982  1104860  60.0  220.0
# 1  핸디/스틱청소기  삼성전자      비스포크 제트 VS20A957E3   649000  60.0  210.0
# 2  핸디/스틱청소기  삼성전자     비스포크 제트 VS20A956AVW   472420  60.0  210.0
# 3  핸디/스틱청소기  삼성전자          제트 VS20T92K0BF   387708  60.0  200.0
# 4  핸디/스틱청소기  LG전자       코드제로 A9S AT9200BA   578000  60.0  200.0

# %%
top_list=danawa_data.sort_values(['흡입력'], ascending=False)
top_list.head()
# Out:
#          카테고리    회사명                        제품      가격  사용시간    흡입력
# 14   핸디/스틱청소기  DIBEA    차이슨 ALLNEW22000 스노우화이트  188000  40.0  400.0
# 37   핸디/스틱청소기  DIBEA           차이슨 ALLNEW29000   65770  48.0  390.0
# 205  핸디/스틱청소기   욜로닉스                    로헨 L30   55790  50.0  350.0
# 91   핸디/스틱청소기  DIBEA  차이슨 ALLNEW22000 (2022년형)  143290  40.0  350.0
# 129  핸디/스틱청소기    디베아                      에어슬림  492630  38.0  300.0

# %%
top_list=danawa_data.sort_values(['사용시간'], ascending=False)
top_list.head()
# Out:
#          카테고리  회사명              제품      가격  사용시간    흡입력
# 209  핸디/스틱청소기  샤오미         드리미 V11  652950  90.0  250.0
# 135  핸디/스틱청소기  샤오미         드리미 V12  143290  90.0  270.0
# 49   핸디/스틱청소기  델로라     V11 파워 300W  909870  70.0  220.0
# 33   핸디/스틱청소기  다이슨  Gen5 디텍트™ 컴플리트  155760  70.0  262.0
# 191  핸디/스틱청소기  샤오미         드리미 T20  492630  70.0  250.0

# %%
top_list=danawa_data.sort_values(['사용시간', '흡입력'], ascending=False)
top_list.head()
# Out:
#          카테고리  회사명              제품      가격  사용시간    흡입력
# 135  핸디/스틱청소기  샤오미         드리미 V12  143290  90.0  270.0
# 209  핸디/스틱청소기  샤오미         드리미 V11  652950  90.0  250.0
# 33   핸디/스틱청소기  다이슨  Gen5 디텍트™ 컴플리트  155760  70.0  262.0
# 191  핸디/스틱청소기  샤오미         드리미 T20  492630  70.0  250.0
# 49   핸디/스틱청소기  델로라     V11 파워 300W  909870  70.0  220.0

# %%
price_mean_value=danawa_data['가격'].mean()
suction_mean_value=danawa_data['흡입력'].mean()
use_time_mean_value=danawa_data['사용시간'].mean()

print('가격 평균값: ', price_mean_value)
print('흡입력 평균값: ', suction_mean_value)
print('사용시간 평균값: ', use_time_mean_value)
# Out:
# 가격 평균값:  433616.72340425535
# 흡입력 평균값:  185.06363636363636
# 사용시간 평균값:  47.945454545454545

# %%
condition_data = danawa_data [
    (danawa_data['가격'] <= price_mean_value) & 
    (danawa_data['흡입력'] >= suction_mean_value) & 
    (danawa_data['사용시간'] >= use_time_mean_value)]
condition_data
# Out:
#          카테고리    회사명                         제품      가격  사용시간    흡입력
# 3    핸디/스틱청소기   삼성전자             제트 VS20T92K0BF  387708  60.0  200.0
# 16   핸디/스틱청소기    샤오미                    드리미 V10  143290  60.0  220.0
# 29   핸디/스틱청소기   LG전자   오브제컬렉션 코드제로 A9S AT9401WC   50220  60.0  210.0
# 30   핸디/스틱청소기    샤오미           TROUVER POWER 11  382230  60.0  200.0
# 33   핸디/스틱청소기    다이슨             Gen5 디텍트™ 컴플리트  155760  70.0  262.0
# 37   핸디/스틱청소기  DIBEA            차이슨 ALLNEW29000   65770  48.0  390.0
# 42   핸디/스틱청소기   LG전자   오브제컬렉션 코드제로 A9S AT9271WB   68990  60.0  210.0
# 43   핸디/스틱청소기   삼성전자         비스포크 제트 VS20B957E5  175280  60.0  220.0
# 44   핸디/스틱청소기    샤오미           TROUVER POWER 12   39800  60.0  220.0
# 45   핸디/스틱청소기   삼성전자         비스포크 제트 VS20B957D4   44900  60.0  220.0
# 54   핸디/스틱청소기   삼성전자         비스포크 제트 VS20B957G5   57900  60.0  220.0
# 57   핸디/스틱청소기   LG전자     오브제컬렉션 코드제로 A9S AU9972  387708  60.0  220.0
# 66   핸디/스틱청소기   LG전자  오브제컬렉션 코드제로 A9S AO9471WKT  157250  60.0  210.0
# 67   핸디/스틱청소기   LG전자   오브제컬렉션 코드제로 A9S AU9672WD   68990  60.0  220.0
# 68   핸디/스틱청소기   LG전자   오브제컬렉션 코드제로 A9S AS9201WB  175280  60.0  210.0
# 80   핸디/스틱청소기   삼성전자           제트 VS20T9218QDCC   57900  60.0  200.0
# 88   핸디/스틱청소기   삼성전자           제트 VS20T9257SECD  188000  60.0  200.0
# 96   핸디/스틱청소기  DIBEA                   올인원25000   44900  55.0  250.0
# 101  핸디/스틱청소기    샤오미                     드리미 V9   89000  60.0  200.0
# 104  핸디/스틱청소기   삼성전자         비스포크 제트 VS20A956E3   50220  60.0  210.0
# 114  핸디/스틱청소기   LG전자  오브제컬렉션 코드제로 A9S AU9872MPD  188000  60.0  220.0
# 119  핸디/스틱청소기   삼성전자         비스포크 제트 VS20A957D2   44900  60.0  210.0
# 132  핸디/스틱청소기   삼성전자             제트 VS20T92P7SD   65770  60.0  200.0
# 133  핸디/스틱청소기   ES산업                    위고 W3CV  188000  60.0  260.0
# 135  핸디/스틱청소기    샤오미                    드리미 V12  143290  90.0  270.0
# 138  핸디/스틱청소기   삼성전자             제트 VS20R9044SA   39800  60.0  200.0
# 155  핸디/스틱청소기   삼성전자   비스포크 제트 VS20A956A3 + 물걸레  175280  60.0  210.0
# 157  핸디/스틱청소기   삼성전자             제트 VS20T9258SD   44900  60.0  200.0
# 172  핸디/스틱청소기   삼성전자             제트 VS20T92P8SD   44800  60.0  200.0
# 176  핸디/스틱청소기    보아스                   VO1000PG   68990  50.0  250.0
# 177  핸디/스틱청소기   LG전자         코드제로 A9S AS9371IKT  175280  60.0  210.0
# 193  핸디/스틱청소기   LG전자          코드제로 A9S AS9370BA   39500  60.0  200.0
# 196  핸디/스틱청소기   LG전자             코드제로 A9S A9700   44800  60.0  200.0
# 199  핸디/스틱청소기   LG전자            코드제로 A9S AS9470  175280  60.0  200.0
# 201  핸디/스틱청소기    샤오미                    로이드미 Z1   39800  60.0  220.0
# 205  핸디/스틱청소기   욜로닉스                     로헨 L30   55790  50.0  350.0
# 220  핸디/스틱청소기  DIBEA                   M500 클래스   44800  50.0  200.0
# 221  핸디/스틱청소기   삼성전자           제트 VS20T9258SDCC   65770  60.0  200.0
# 231  핸디/스틱청소기   LG전자            코드제로 A9S AS9471   55790  60.0  210.0

# %% [markdown]
# ### 7.4.3 데이터 시각화

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import seaborn as sns
import platform 

font_path = ''
if platform.system() == 'Windows': 
    font_path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname = font_path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    font_path = '/Users/$USER/Library/Fonts/AppleGothic.ttf'
    rc('font', family = 'AppleGothic')
else: 
    print('Check your OS system')
    
# %matplotlib inline

# %%
chart_data = danawa_data.dropna(axis = 0)
len(chart_data)
# Out:
# 159

# %%
suction_max_value = chart_data['흡입력'].max()
suction_mean_value = chart_data['흡입력'].mean()
use_time_max_value = chart_data['사용시간'].max()
use_time_mean_value = chart_data['사용시간'].mean()

# %%
plt.figure(figsize=(20, 10))
plt.title("무선 핸디/스틱청소기 차트")
sns.scatterplot(x = '흡입력', y = '사용시간', size = '가격', hue = chart_data['회사명'], 
             data = chart_data, sizes = (10, 1000), legend = False)
plt.plot([0, suction_max_value], 
          [use_time_mean_value, use_time_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [0, use_time_max_value], 
          'r--', 
          lw = 1 )
plt.show()

# %% [markdown]
# ### 7.4.4 인기 제품의 데이터 시각화

# %%
chart_data_selected = chart_data[:20]
len(chart_data_selected)
chart_data_selected
# Out:
#         카테고리    회사명                        제품       가격  사용시간    흡입력
# 0   핸디/스틱청소기   LG전자    오브제컬렉션 코드제로 A9S AU9982  1104860  60.0  220.0
# 1   핸디/스틱청소기   삼성전자        비스포크 제트 VS20A957E3   649000  60.0  210.0
# 2   핸디/스틱청소기   삼성전자       비스포크 제트 VS20A956AVW   472420  60.0  210.0
# 3   핸디/스틱청소기   삼성전자            제트 VS20T92K0BF   387708  60.0  200.0
# 4   핸디/스틱청소기   LG전자         코드제로 A9S AT9200BA   578000  60.0  200.0
# 5   핸디/스틱청소기   삼성전자        비스포크 제트 VS20B956AX   545000  60.0  220.0
# 7   핸디/스틱청소기   LG전자           코드제로 A9S AS9271   536350  60.0  210.0
# 8   핸디/스틱청소기   삼성전자        비스포크 제트 VS20A956A3   456890  60.0  210.0
# 9   핸디/스틱청소기    다이슨               V10 플러피 오리진   492630  60.0  151.0
# 10  핸디/스틱청소기   삼성전자        비스포크 제트 VS20B957D5   686030  60.0  220.0
# 11  핸디/스틱청소기   LG전자    오브제컬렉션 코드제로 A9S AO9571   938060  60.0  210.0
# 12  핸디/스틱청소기   LG전자         코드제로 A9S AT9270IA   644730  60.0  200.0
# 13  핸디/스틱청소기   LG전자  오브제컬렉션 코드제로 A9S AU9602WD   794750  60.0  220.0
# 14  핸디/스틱청소기  DIBEA    차이슨 ALLNEW22000 스노우화이트   188000  40.0  400.0
# 15  핸디/스틱청소기   LG전자    오브제컬렉션 코드제로 A9S AU9882  1082820  60.0  220.0
# 16  핸디/스틱청소기    샤오미                   드리미 V10   143290  60.0  220.0
# 19  핸디/스틱청소기   LG전자           코드제로 A9S AT9471   773330  60.0  210.0
# 20  핸디/스틱청소기   LG전자         코드제로 A9S AS9201IB   496340  60.0  210.0
# 21  핸디/스틱청소기   LG전자         코드제로 A9S AS9200BA   531910  60.0  200.0
# 22  핸디/스틱청소기   삼성전자        비스포크 제트 VS20B956D5   584000  60.0  220.0

# %%
suction_max_value = chart_data_selected['흡입력'].max()
suction_mean_value = chart_data_selected['흡입력'].mean()
use_time_max_value = chart_data_selected['사용시간'].max()
use_time_mean_value = chart_data_selected['사용시간'].mean()
plt.figure(figsize=(20, 10))
plt.title("무선 핸디/스틱청소기 TOP 20")
sns.scatterplot(x = '흡입력', 
                  y = '사용시간', 
                  size = '가격', 
                  hue = chart_data_selected['회사명'], 
                  data = chart_data_selected, sizes = (100, 2000),
                  legend = False)
plt.plot([60, suction_max_value], 
          [use_time_mean_value, use_time_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [20, use_time_max_value], 
          'r--', 
          lw = 1 )
for index, row in chart_data_selected.iterrows():
    x = row['흡입력']
    y = row['사용시간']
    s = row['제품'].split(' ')[0]
    plt.text(x, y, s, size=20)
plt.show()

# %%
suction_max_value = chart_data_selected['흡입력'].max()
suction_mean_value = chart_data_selected['흡입력'].mean()
use_price_max_value = chart_data_selected['가격'].max()
use_price_mean_value = chart_data_selected['가격'].mean()
plt.figure(figsize=(20, 10))
plt.title("무선 핸디/스틱청소기 TOP 20")
sns.scatterplot(x = '흡입력', 
                  y = '가격', 
                  size = '사용시간', 
                  hue = chart_data_selected['회사명'], 
                  data = chart_data_selected, sizes = (100, 2000),
                  legend = False)
plt.plot([60, suction_max_value], 
          [use_price_mean_value, use_price_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [20, use_price_max_value], 
          'r--', 
          lw = 1 )
for index, row in chart_data_selected.iterrows():
    x = row['흡입력']
    y = row['가격']
    s = row['제품'].split(' ')[0]
    plt.text(x, y, s, size=20)
plt.show()
